# %% [markdown]
# ### Q1. What is Flask Framework? What are the advantages of Flask Framework?

# %% [markdown]
# Flask is a micro web framework written in Python1. It’s a Python module that lets you develop web applications easily. It has a small and easy-to-extend core. It does have many cool features like URL routing, template engine.
#
# Advantages of Flask Framework are:
#
# Scalable: Flask can be used to quickly grow technological projects like web apps3.
# Flexible: This is the most crucial aspect of Flask and one of its key benefits3.
# Simple Negotiation: Flask allows web developers to focus entirely on coding without becoming bogged down3.
# Lightweight: Flask is lightweight to enable you to transit into a web framework easily4.
# Easy to Understand: Its simplicity gives you the opportunity to understand it better and learn from it4.
# Testing: Flask allows for unit testing through its integrated support4.

# %% [markdown]
# ### Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in Jupyter Notebook.

# %% [markdown]
# ![Screenshot (335).png](attachment:8d845ec3-d0de-44d8-93e5-8e1b37dac1bf.png)

# %% [markdown]
# ### Q3. What is App routing in Flask? Why do we use app routes?

# %% [markdown]
# #### Ans:
# App routing in Flask is the process of mapping URLs to specific functions or views in a web application. It’s achieved through the use of decorators, which are special annotations that can be applied to Python functions. These decorators define how different URLs should be handled by Flask, and what functions or views should be executed when those URLs are accessed.

# %% [markdown]
# ### Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/” route to show the following details:
# ### Company Name: ABC Corporation
# ### Location: India
# ### Contact Detail: 999-999-9999

# %% [markdown]
# ![Screenshot (336).png](attachment:115e96b9-e188-4a40-af65-a3d1db5a9120.png)![Screenshot (337).png](attachment:ba5f7e4f-964a-4ea0-b470-dd9f618a7952.png)

# %% [markdown]
# ### Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the url_for() function.

# %% [markdown]
# #### Ans:
# In Flask, the url_for() function is used for URL building. It generates a URL for the given endpoint with the method defined. The returned URL is always absolute, never relative.

# %%
from flask import Flask, url_for

app = Flask(__name__)

@app.route('/')
def index():
    return "Home Page"

@app.route('/hello')
def hello():
    return "Hello World!"

with app.test_request_context():
    print(url_for('index'))
    print(url_for('hello'))
